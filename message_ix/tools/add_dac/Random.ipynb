# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [*range(1,1001)]
log_x = [np.log10(e) for e in x]

plt.plot(log_x,x)
plt.xlabel('log_x')
plt.ylabel('x')
plt.savefig('log.png',dpi=600)
plt.show()
